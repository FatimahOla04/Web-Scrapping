# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests 
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np

# %%
path="https://www.jumia.com.ng/catalog/?q=ram&page=2#catalog-listing"
getrequest=requests.get(path)

# %%
getrequst
# Out:
# <Response [200]>

# %%
html_content=getrequest.content

# %%
html_content
# Out:
# b'<!DOCTYPE html><html lang="en" dir="ltr"><head><meta charset="utf-8"/><title>Shop All Products - TVs, Laptops, Fashion Items | Jumia Nigeria</title><meta property="og:type" content="product"/><meta property="og:site_name" content="Jumia Nigeria"/><meta property="og:title" content="Shop All Products - TVs, Laptops, Fashion Items | Jumia Nigeria"/><meta property="og:description" content="Enjoy amazing discounts and deals up to 70% on your favourite iPhones, android devices, TVs, Cookers and more offers at the best prices on Jumia Nigeria."/><meta property="og:url" content="/catalog/"/><meta property="og:image" content="https://ng.jumia.is/cms/jumialogonew.png"/><meta property="og:locale" content="en_NG"/><meta name="title" content="Shop All Products - TVs, Laptops, Fashion Items | Jumia Nigeria"/><meta name="robots" content="noindex,follow"/><meta name="description" content="Enjoy amazing discounts and deals up to 70% on your favourite iPhones, android devices, TVs, Cookers and more 
# ...

# %%
soup=bs(html_content)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
single_item=soup.find("div",{"class":"info"})

# %%
single_item
# Out:
# <div class="info"><div class="bdg _glb _xs">Shipped from abroad</div><h3 class="name">JingHai 1.2V DDR4 2666MHz 8GB PC Memory RAM Module</h3><div class="prc">₦ 64,710</div><div class="s-prc-w"><div class="old">₦ 92,442</div><div class="bdg _dsct _sm">30%</div></div></div>

# %%
item_name=single_item.find("h3", {"class":"name"}).text
item_name
# Out:
# 'JingHai 1.2V DDR4 2666MHz 8GB PC Memory RAM Module'

# %%
description=single_item.find("div", {"class":"bdg _glb _xs"}).text
description
# Out:
# 'Shipped from abroad'

# %%
new_price=single_item.find("div", {"class":"prc"}).text
new_price
# Out:
# '₦ 64,710'

# %%
old_price=single_item.find("div", {"class": "old"}).text
old_price
# Out:
# '₦ 92,442'

# %%
all_item=soup.findAll("div",{"class":"info"})

# %%
for i in all_item:
    print(i.find("h3", {"class":"name"}).text)
# Out:
# JingHai 1.2V DDR4 2666MHz 8GB PC Memory RAM Module
# Walram DDR4 4GB PC Desktop Computer 2666MHz Ram 1.5V UDIMM
# XIEDE X059 DDR4 Laptop RAM, Memory Capacity: 16GB-2133MHz 16GB Fully
# XIEDE X021 DDR2 800MHz 4GB Memory RAM Module
# JingHai 1.2V DDR4 2666MHz 16GB Memory RAM Module
# JingHai 1.5V DDR3 1600MHz 8GB Memory RAM Module For Laptop
# XIEDE X049 DDR4 2133MHz 8GB Memory RAM Module
# Vaseky 8GB 2400MHz PC4-19200 DDR4 PC Memory RAM Module
# Vaseky 8GB 1600MHz AMD PC3-12800 DDR3 PC Memory RAM Module
# XIEDE X040 DDR3 1600MHz 4GB Memory RAM Module
# Vaseky 8GB 2400MHz PC4-19200 DDR4 PC Memory RAM Module
# OR Suitable For Dell 0G176J Server Hard Drive Bay R720 R710 R610 Hard Drive Bay
# JingHai 1.5V DDR3 1600MHz 8GB Memory RAM Module for Laptop
# Vaseky 4GB 1600MHz PC3-12800 DDR3 PC Memory RAM Module
# JingHai 1.5V DDR3 1600MHz 8GB Memory RAM Module For Laptop
# XIEDE X041 DDR3 1600MHz 8GB Memory RAM Module
# XIEDE X043 DDR3 1333MHz 4GB 1.5V Memory RAM Module
# ...

# %%
item_name=[]
description=[]
new_price=[]
old_price=[]


for i in all_item:
    try:
        item_name.append( i.find("h3", {"class":"name"}).text)
    except:
        item_name.append(np.nan)
    try:
        description.append(i.find("div", {"class":"bdg _glb _xs"}).text)
    except:
        description.append(np.nan)
        
        
dict_all = {"Item Name":item_name, "Shipment Mode": description}

# %%
dict_all
# Out:
# {'Item Name': ['JingHai 1.2V DDR4 2666MHz 8GB PC Memory RAM Module',
#   'Walram DDR4 4GB PC Desktop Computer 2666MHz Ram 1.5V UDIMM',
#   'XIEDE X059 DDR4 Laptop RAM, Memory Capacity: 16GB-2133MHz 16GB Fully',
#   'XIEDE X021 DDR2 800MHz 4GB Memory RAM Module',
#   'JingHai 1.2V DDR4 2666MHz 16GB Memory RAM Module',
#   'JingHai 1.5V DDR3 1600MHz 8GB Memory RAM Module For Laptop',
#   'XIEDE X049 DDR4 2133MHz 8GB Memory RAM Module',
#   'Vaseky 8GB 2400MHz PC4-19200 DDR4 PC Memory RAM Module',
#   'Vaseky 8GB 1600MHz AMD PC3-12800 DDR3 PC Memory RAM Module',
#   'XIEDE X040 DDR3 1600MHz 4GB Memory RAM Module',
#   'Vaseky 8GB 2400MHz PC4-19200 DDR4 PC Memory RAM Module',
#   'OR Suitable For Dell 0G176J Server Hard Drive Bay R720 R710 R610 Hard Drive Bay',
#   'JingHai 1.5V DDR3 1600MHz 8GB Memory RAM Module for Laptop',
#   'Vaseky 4GB 1600MHz PC3-12800 DDR3 PC Memory RAM Module',
#   'JingHai 1.5V DDR3 1600MHz 8GB Memory RAM Module For Laptop',
# ...

# %%
pd.DataFrame(dict_all)
# Out:
#                                             Item Name        Shipment Mode
# 0   JingHai 1.2V DDR4 2666MHz 8GB PC Memory RAM Mo...  Shipped from abroad
# 1   Walram DDR4 4GB PC Desktop Computer 2666MHz Ra...                  NaN
# 2   XIEDE X059 DDR4 Laptop RAM, Memory Capacity: 1...  Shipped from abroad
# 3        XIEDE X021 DDR2 800MHz 4GB Memory RAM Module  Shipped from abroad
# 4    JingHai 1.2V DDR4 2666MHz 16GB Memory RAM Module  Shipped from abroad
# 5   JingHai 1.5V DDR3 1600MHz 8GB Memory RAM Modul...  Shipped from abroad
# 6       XIEDE X049 DDR4 2133MHz 8GB Memory RAM Module  Shipped from abroad
# 7   Vaseky 8GB 2400MHz PC4-19200 DDR4 PC Memory RA...  Shipped from abroad
# 8   Vaseky 8GB 1600MHz AMD PC3-12800 DDR3 PC Memor...  Shipped from abroad
# 9       XIEDE X040 DDR3 1600MHz 4GB Memory RAM Module  Shipped from abroad
# 10  Vaseky 8GB 2400MHz PC4-19200 DDR4 PC Memory RA...  Shipped from abroad
# ...
